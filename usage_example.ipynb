# %% [markdown]
# <a href="https://colab.research.google.com/github/rollno4/tensorflow/blob/0.6.0/usage_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The following code is a usage example of tf.image.flip_up_down

# %%
import tensorflow as tf

def flip_up_down():
  '''
  Example usage:
  >>>image = tf.random.normal()
  >>>tf.image.flip_up_down()

  Returns:
  <tf.Tensor 'flip_up_down/ReverseV2:0' shape=(245, 245, 2) dtype=float32>
  
  Args:
  image: 4-D Tensor of shape [batch, height, width, channels] or 3-D Tensor of shape [height, width, channels].
  '''

image = tf.random.normal(shape=(245, 245, 2))
tf.image.flip_up_down(image)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# <tf.Tensor 'flip_up_down/ReverseV2:0' shape=(245, 245, 2) dtype=float32>
